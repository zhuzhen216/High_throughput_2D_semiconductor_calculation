# %%
import pandas as pd
import numpy as np

# %%
SemiInfo_df = pd.read_csv('2D_semiconductor.csv')

# %%
SemiInfo_df.head()
# Out:
#    Unnamed: 0 Compound Phase  Band gap (eV)  VBM (eV)  CBM (eV)  \
# 0           0        N   N_1       3.880865 -1.074865  2.826865
# 1           1        N   N_2       0.000000  2.756552  2.756552
# 2           2        P   P_0       0.902202 -1.750202 -0.839798
# 3           3        P   P_1       1.933175 -3.833175 -1.889825
# 4           4       As  As_0       0.806833 -2.091833 -1.277167
#
#    Compound mass Compound type  Phase index  Average radius  HSE-gap (eV)  \
# 0        14.0067             V            1            56.0      0.000000
# 1        14.0067             V            2            56.0      0.000000
# 2        30.9738             V            0            98.0      1.736824
# 3        30.9738             V            1            98.0      2.981880
# 4        74.9216             V            0           114.0      1.552500
#
#    HSE-VBM (eV)  HSE-CBM (eV)  Vacuum level (eV)  VBM absolute (eV)  \
# ...
